# %%
import pandas as pd
import csv
import seaborn as sns

# %%
df = pd.read_csv("BicycleParking.csv")
df
# Out:
#                                             the_geom  OBJECTID  BoroCode  \
# 0       POINT (-73.94665719000373 40.71131121432156)         1         3
# 1      POINT (-73.88760259761078 40.665945152097834)         2         3
# 2       POINT (-73.88760190075236 40.66593971499823)         3         3
# 3      POINT (-73.88760119582628 40.665939767439966)         4         3
# 4      POINT (-73.88760120507663 40.665934277899765)         5         3
# ...                                              ...       ...       ...
# 30314   POINT (-73.98873699981141 40.75880799972076)     30315         1
# 30315  POINT (-73.95666899976742 40.717221000422306)     30316         3
# 30316  POINT (-73.95660500049034 40.717176000336394)     30317         3
# 30317  POINT (-73.95666899976742 40.717221000422306)     30318         3
# 30318  POINT (-73.95656399999784 40.717151999786275)     30319         3
#
#         BoroName  BoroCD  CounDist  AssemDist  StSenDist  CongDist  \
# ...

# %%
df.describe()
# Out:
#            OBJECTID      BoroCode        BoroCD      CounDist     AssemDist  \
# count  30319.000000  30319.000000  30319.000000  30319.000000  30319.000000
# mean   15160.000000      2.568258    263.372506     23.900953     56.325011
# std     8752.485742      1.161344    116.201836     15.161426     16.550185
# min        1.000000      1.000000    101.000000      1.000000     23.000000
# 25%     7580.500000      1.000000    111.000000      8.000000     44.000000
# 50%    15160.000000      3.000000    302.000000     26.000000     53.000000
# 75%    22739.500000      3.000000    315.000000     37.000000     70.000000
# max    30319.000000      5.000000    503.000000     51.000000     87.000000
#
#           StSenDist      CongDist        REQBBL       HrcEvac
# count  30319.000000  30319.000000  2.727600e+04  11395.000000
# mean      26.987862      9.992447  2.478985e+09      4.227644
# std       12.023247      2.882024  1.172284e+09      1.599310
# ...

# %%
df.head(10) #returns top ten, can use .tail() to return bottom
# Out:
#                                         the_geom  OBJECTID  BoroCode  \
# 0   POINT (-73.94665719000373 40.71131121432156)         1         3
# 1  POINT (-73.88760259761078 40.665945152097834)         2         3
# 2   POINT (-73.88760190075236 40.66593971499823)         3         3
# 3  POINT (-73.88760119582628 40.665939767439966)         4         3
# 4  POINT (-73.88760120507663 40.665934277899765)         5         3
# 5   POINT (-73.88760260686104 40.66593966255764)         6         3
# 6    POINT (-73.9945282478299 40.66363297930996)         7         3
# 7   POINT (-73.99453048070198 40.66363082448108)         8         3
# 8  POINT (-73.99453271239138 40.663628669652134)         9         3
# 9   POINT (-73.99171687784074 40.66287806252868)        10         3
#
#    BoroName  BoroCD  CounDist  AssemDist  StSenDist  CongDist        REQBBL  \
# 0  Brooklyn     301        34         53         18         7  3.027870e+09
# ...

# %%
df.dtypes #shows data types
#object means its a string
# Out:
# the_geom       object
# OBJECTID        int64
# BoroCode        int64
# BoroName       object
# BoroCD          int64
# CounDist        int64
# AssemDist       int64
# StSenDist       int64
# CongDist        int64
# REQBBL        float64
# IFOADDRESS     object
# STREETON       object
# XSTREET1       object
# XSTREET2       object
# SIDE           object
# PROGRAM        object
# ASSETSUBTY     object
# DATE_INST      object
# INTERNALID     object
# NTAName        object
# FEMAFldz       object
# FEMAFldT       object
# HrcEvac       float64
# dtype: object

# %%
df.columns #shows us our columns as well
# Out:
# Index(['the_geom', 'OBJECTID', 'BoroCode', 'BoroName', 'BoroCD', 'CounDist',
#        'AssemDist', 'StSenDist', 'CongDist', 'REQBBL', 'IFOADDRESS',
#        'STREETON', 'XSTREET1', 'XSTREET2', 'SIDE', 'PROGRAM', 'ASSETSUBTY',
#        'DATE_INST', 'INTERNALID', 'NTAName', 'FEMAFldz', 'FEMAFldT',
#        'HrcEvac'],
#       dtype='object')

# %%
#check to see if there are any null values
cols = df.columns #creating a list of columns
sns.heatmap(df[cols].isnull()) #checking for null values. STREETON is the one that lacks the most data
# Out:
# <AxesSubplot:>

# %%
df_2 = df.copy()

df_2.dropna() #drops all of the rows that has NaN(null) values in them
#notice that we've lost a TON of data, maybe that isn't the best option
# Out:
#                                             the_geom  OBJECTID  BoroCode  \
# 24      POINT (-73.94439719036913 40.70453351068332)        25         3
# 27      POINT (-73.97957381255492 40.68278716757816)        28         3
# 42      POINT (-73.84936118046443 40.73296856945365)        43         4
# 43     POINT (-73.84936453999438 40.732967568879815)        44         4
# 79      POINT (-73.84906811675575 40.73238061316713)        80         4
# ...                                              ...       ...       ...
# 30270   POINT (-73.94523299952407 40.74765100008488)     30271         4
# 30315  POINT (-73.95666899976742 40.717221000422306)     30316         3
# 30316  POINT (-73.95660500049034 40.717176000336394)     30317         3
# 30317  POINT (-73.95666899976742 40.717221000422306)     30318         3
# 30318  POINT (-73.95656399999784 40.717151999786275)     30319         3
#
#        BoroName  BoroCD  CounDist  AssemDist  StSenDist  CongDist  \
# ...

# %%
#instead, let's fill those NaN values
#the "street on" column seems most appropriate for now
#now whent this is run, on the heatmap, STREETON is now totally black
df["STREETON"] = df["STREETON"].fillna("No Street Specified")
df
# Out:
#                                             the_geom  OBJECTID  BoroCode  \
# 0       POINT (-73.94665719000373 40.71131121432156)         1         3
# 1      POINT (-73.88760259761078 40.665945152097834)         2         3
# 2       POINT (-73.88760190075236 40.66593971499823)         3         3
# 3      POINT (-73.88760119582628 40.665939767439966)         4         3
# 4      POINT (-73.88760120507663 40.665934277899765)         5         3
# ...                                              ...       ...       ...
# 30314   POINT (-73.98873699981141 40.75880799972076)     30315         1
# 30315  POINT (-73.95666899976742 40.717221000422306)     30316         3
# 30316  POINT (-73.95660500049034 40.717176000336394)     30317         3
# 30317  POINT (-73.95666899976742 40.717221000422306)     30318         3
# 30318  POINT (-73.95656399999784 40.717151999786275)     30319         3
#
#         BoroName  BoroCD  CounDist  AssemDist  StSenDist  CongDist  \
# ...

# %%
cols = df.columns #creating a list of columns
sns.heatmap(df[cols].isnull())
# Out:
# <AxesSubplot:>

# %%
#dropna and fillna are very useful when it comes to pandas

# %%
#now it's probably better to work with a slightly smaller set of columns
#because so many of them do not have information that is relevant o us
df_3 = df.copy()

df_3.drop(labels = ["the_geom", "REQBBL"], axis=1,inplace=True)
#axis=1 tells it to drop columns, the inplace=True has it affect the df itself

df_3
# Out:
#        OBJECTID  BoroCode   BoroName  BoroCD  CounDist  AssemDist  StSenDist  \
# 0             1         3   Brooklyn     301        34         53         18
# 1             2         3   Brooklyn     305        42         60         19
# 2             3         3   Brooklyn     305        42         60         19
# 3             4         3   Brooklyn     305        42         60         19
# 4             5         3   Brooklyn     305        42         60         19
# ...         ...       ...        ...     ...       ...        ...        ...
# 30314     30315         1  Manhattan     104         3         75         47
# 30315     30316         3   Brooklyn     301        33         50         59
# 30316     30317         3   Brooklyn     301        33         50         59
# 30317     30318         3   Brooklyn     301        33         50         59
# 30318     30319         3   Brooklyn     301        33         50         59
#
# ...

# %%
df_3.DATE_INST = df_3.DATE_INST.str[6:10]
df_3.DATE_INST
#getting a specific year of a column. Like for this, there was time and date but we just want year of date
# Out:
# 0        2013
# 1        2012
# 2        2012
# 3        2012
# 4        2012
#          ...
# 30314    2023
# 30315    2017
# 30316    2017
# 30317    2017
# 30318    2017
# Name: DATE_INST, Length: 30319, dtype: object

# %%
df_3.IFOADDRESS = df_3.IFOADDRESS.str.replace('\d+','') 
#we are replacing column, IFOADDRESS, and to replace all digits, as represented as '\d+', 
#replace with nothing. Therefore, for example, for the first row it was like 638 GRAND ST but now its only GRAND ST
df_3
# Out:
# /var/folders/kc/4grnk0s94fn_60px6x1w0wbc0000gn/T/ipykernel_37893/3121383091.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_3.IFOADDRESS = df_3.IFOADDRESS.str.replace('\d+','')
#        OBJECTID  BoroCode   BoroName  BoroCD  CounDist  AssemDist  StSenDist  \
# 0             1         3   Brooklyn     301        34         53         18
# 1             2         3   Brooklyn     305        42         60         19
# 2             3         3   Brooklyn     305        42         60         19
# 3             4         3   Brooklyn     305        42         60         19
# 4             5         3   Brooklyn     305        42         60         19
# ...         ...       ...        ...     ...       ...        ...        ...
# 30314     30315         1  Manhattan     104         3         75         47
# 30315     30316         3   Brooklyn     301        33         50         59
# ...

# %%
bikes = df_3["BoroName"]
bike_dict = {}

for i in bikes: 
    if i not in bike_dict:
        bike_dict[i]=1
    else:
        bike_dict[i]+=1
        
print(bike_dict)
# Out:
# {'Brooklyn': 11734, 'Bronx': 3411, 'Manhattan': 8543, 'Queens': 5855, 'Staten Island': 776}

# %%
df_3.DATE_INST = df_3.DATE_INST.fillna("No Date")
df_3 = df_3.sort_values("DATE_INST", ascending=True)

# %%
#Nasa photo of the day program
import requests
import json
import requests
from IPython import display

def generate_photo():
    API_key = "epcKNrFaZ71sfrNBhpDllJFyzvMWWAjeNIA9hMxz"
    date = input("Select a date after June 16, 1995. Enter in YYYY-MM-DD format: ")
    photo = requests.get(f"https://api.nasa.gov/planetary/apod?api_key={API_key}&date={date}").json()
    url = photo["url"]
    
    print(url)
    display.Image(url)

generate_photo()
# Out:
# Select a date after June 16, 1995. Enter in YYYY-MM-DD format: 2004-10-10
# https://apod.nasa.gov/apod/image/0410/sun2_trace.jpg

# %%
import requests
import json
import os
from PIL import Image

def get_data(api_key):
    raw_response = requests.get(f'https://api.nasa.gov/planetary/apod?api_key={api_key}').text
    response = json.loads(raw_response)
    return response


def get_date(response):
    date = response['date']
    return date


def get_explaination(response):
    explaination = response['explanation']
    return explaination


def get_hdurl(response):
    hdurl = response['hdurl']
    return hdurl


def get_media_type(response):
    media_type = response['media_type']
    return media_type

def get_service_version(response): 
    service_version = response['service_version']
    return service_version


def get_title(response):
    service_version = response['title']
    return service_version

def get_url(response):
    url = response['url']
    return url

def download_image(url, date):
    if os.path.isfile(f'{date}.png') == False:
        raw_image = requests.get(url).content
        with open(f'{date}.jpg', 'wb') as file:
            file.write(raw_image)
            
    else:
        return FileExistsError


def convert_image(image_path):
    path_to_image = os.path.normpath(image_path)

    basename = os.path.basename(path_to_image)

    filename_no_extension = basename.split(".")[0]

    base_directory = os.path.dirname(path_to_image)

    image = Image.open(path_to_image)
    image.save(f"{base_directory}/{filename_no_extension}.png")

# %%
#LAB EXERCISE

# %%
#PART I

import pandas as pd
import csv
import seaborn as sns

wf = pd.read_csv("AB_NYC_2019.csv")
wf

#WHAT COULD BE SOME USES FOR DATASET

#This data could be used to see which airbnbs or even general, neighborhoods are the most popular
#This could be done by analyzing the calculated number of listings, identifying the most popular Airbnbs and
#the most popular neighborhoods for airbnbs.

#This data could be particularly helpful for airbnb investors to better understand the market.
#By analyzing how the prices of 2019 airbnb's compare to those offered now, they can identify
#trends and fluctuations in demand, which can inform them of better pricing strategies.
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
#Seaborn map to find all the NaN values
cols = wf.columns #creating a list of columns
sns.heatmap(wf[cols].isnull())
# Out:
# <AxesSubplot:>

# %%
#replace those NaN values that were in the seaborn map
wf["last_review"] = wf["last_review"].fillna("Date Not Specified")
wf["reviews_per_month"] = wf["reviews_per_month"].fillna("Reviews Not Specified")
wf
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
#isolate just the year from the last_review column 
wf.last_review = wf.last_review.str[0:4]
wf.last_review
# Out:
# 0        2018
# 1        2019
# 2        Date
# 3        2019
# 4        2018
#          ...
# 48890    Date
# 48891    Date
# 48892    Date
# 48893    Date
# 48894    Date
# Name: last_review, Length: 48895, dtype: object

# %%
#one other thing with the dataset of my choosing
#I figured the host name, exact lattitude, and longitude were not very necessary
wf.drop(labels = ["host_name", "latitude", "longitude"], axis=1,inplace=True)
#axis=1 tells it to drop columns, the inplace=True has it affect the df itself

wf
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
#PART II

import requests
import json

def generate_book():
    API_KEY = "AIzaSyBIqhXR3mSaZUE1sYXTelJ2P5gF6TOEv9o"
    search = input("Search: ")
    response = requests.get(f"https://www.googleapis.com/books/v1/volumes?q={search}&key={API_KEY}")
    data = json.loads(response.text)
    books = data.get('items', [])
    return books

def url(book):
    return book['selfLink']

def thumbnail(book):
    return book['volumeInfo'].get('imageLinks', {}).get('thumbnail', '')

def title(book):
    return book['volumeInfo'].get('title', '')

def description(book):
    return book['volumeInfo'].get('description', '')

def pageCount(book):
    return book['volumeInfo'].get('pageCount', '')

def averageRating(book):
    return book['volumeInfo'].get('averageRating', '')
